# %%
import sudo_solo

# %% [markdown]
# ## 新建棋盘

# %%
new_table=sudo_solo.creat_table()

# %%
new_table
# Out:
#     row_num  col_num group_key   num_list  num_real
# 0         1        1         a  123456789         0
# 1         2        1         a  123456789         0
# 2         3        1         a  123456789         0
# 3         4        1         b  123456789         0
# 4         5        1         b  123456789         0
# ..      ...      ...       ...        ...       ...
# 76        5        9         h  123456789         0
# 77        6        9         h  123456789         0
# 78        7        9         i  123456789         0
# 79        8        9         i  123456789         0
# 80        9        9         i  123456789         0
#
# [81 rows x 5 columns]

# %% [markdown]
# ## 录入开局信息

# %%
start_nums=[
    1,2,4,
    1,3,6,
    1,4,9,
    1,6,3,
    2,3,3,
    2,5,5,
    2,8,6,
    3,1,9,
    3,6,2,
    3,9,3,
    4,3,5,
    4,6,6,
    5,1,8,
    5,8,1,
    6,2,1,
    6,4,7,
    6,5,8,
    6,7,2,
    7,8,5,
    8,2,8,
    8,3,1,
    8,4,3,
    8,9,7,
    9,4,8,
    9,7,1,
    9,9,4   
    
]

# %%
sudo_solo.start_table(new_table,start_nums)

# %%
new_table
# Out:
#     row_num  col_num group_key   num_list  num_real
# 0         1        1         a  123456789         0
# 1         2        1         a  123456789         0
# 2         3        1         a          9         9
# 3         4        1         b  123456789         0
# 4         5        1         b          8         8
# ..      ...      ...       ...        ...       ...
# 76        5        9         h  123456789         0
# 77        6        9         h  123456789         0
# 78        7        9         i  123456789         0
# 79        8        9         i          7         7
# 80        9        9         i          4         4
#
# [81 rows x 5 columns]

# %%
sudo_solo.show_table(new_table)
# Out:
# col_num                    1          2          3          4          5  \
# row_num group_key
# 1       a          123456789          4          6
#         d                                                   9  123456789
#         g
# 2       a          123456789  123456789          3
#         d                                           123456789          5
#         g
# 3       a                  9  123456789  123456789
#         d                                           123456789  123456789
#         g
# 4       b          123456789  123456789          5
#         e                                           123456789  123456789
#         h
# 5       b                  8  123456789  123456789
#         e                                           123456789  123456789
#         h
# 6       b          123456789          1  123456789
#         e                                                   7          8
#         h
# 7       c          123456789  123456789  123456789
# ...

# %% [markdown]
# ## 更新棋盘信息

# %%
new_table=sudo_solo.update_table(new_table)
# Out:
# start to check if there has num_real to update

# %%
sudo_solo.show_table(new_table)
# Out:
# col_num                1       2     3     4       5     6       7      8  \
# row_num group_key
# 1       a           1257       4     6
#         d                                  9      17     3
#         g                                                      578    278
# 2       a            127      27     3
#         d                                 14       5  1478
#         g                                                     4789      6
# 3       a              9      57    78
#         d                                146    1467     2
#         g                                                     4578    478
# 4       b           2347    2379     5
#         e                                124   12349     6
#         h                                                    34789  34789
# 5       b              8   23679  2479
#         e                                245    2349   459
#         h                                                   345679      1
# ...
